# %% [markdown]
# <a href="https://colab.research.google.com/github/halfmoonliu/example-graphrag/blob/main/Evaluate_10202024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retrieval Augmented Medical Question Answering
#
# Yun-Chung Liu (yl974) </br></br>
#
# This notebook demonstrates how to **apply RAG** (Retrieval Augmented Generation) to generate **long answers** (conclusion, or summary) to **Medical Questions** (generated from research papers on PubMed).

# %%
# import libraries
! pip install datasets

from datasets import Dataset, DatasetDict, load_dataset
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import transformers
from transformers import AdamW, AutoTokenizer, BertModel, BertTokenizer
from transformers import GPT2Tokenizer, GPT2Model
from transformers import pipeline, set_seed
from nltk.translate.bleu_score import sentence_bleu
# !pip install evaluate
# !pip install rouge-score
import evaluate

# import libraries
from google.colab import drive

# for dataset access
drive.mount('/content/drive')

# %%
# print version
print(transformers.__version__)
# Out:
# 4.40.1

# %% [markdown]
# ##  I. Dataset
#
# The dataset used for this project is PubMedQA. The PubMedQA[1] dataset contains questions generated with research papers on PubMed, one of the most popular database for biomedical research worldwide. The dataset has three sets of data: *labeled*, *unlabeled*, and *artificial*, depending on ways the questions and answers were generated.
#
# The questions were obtained from research papers whose title is a questions. For each question, there is a short answer (yes/no) and a long answer (usually the conclusion of the abstract). Below is an example:

# %%
Dataset_l_raw = load_dataset("qiaojin/PubMedQA", "pqa_labeled")

# %%
# an example of the labeled dataset
Dataset_l_raw['train'][0]
# Out:
# {'pubid': 21645374,
#  'question': 'Do mitochondria play a role in remodelling lace plant leaves during programmed cell death?',
#  'context': {'contexts': ['Programmed cell death (PCD) is the regulated death of cells within an organism. The lace plant (Aponogeton madagascariensis) produces perforations in its leaves through PCD. The leaves of the plant consist of a latticework of longitudinal and transverse veins enclosing areoles. PCD occurs in the cells at the center of these areoles and progresses outwards, stopping approximately five cells from the vasculature. The role of mitochondria during PCD has been recognized in animals; however, it has been less studied during PCD in plants.',
#    'The following paper elucidates the role of mitochondrial dynamics during developmentally regulated PCD in vivo in A. madagascariensis. A single areole within a window stage leaf (PCD is occurring) was divided into three areas based on the progression of PCD; cells that will not undergo PCD (NPCD), cells in early stages of PCD (EPCD), and cells in late stages of PCD (LPCD). Window stage leaves were stained with the mitochondrial dye MitoTracker Red CMXRos and examined. Mitochondrial dynamics were delineated into four categories (M1-M4) based on characteristics including distribution, motility, and membrane potential (ΔΨm). A TUNEL assay showed fragmented nDNA in a gradient over these mitochondrial stages. Chloroplasts and transvacuolar strands were also examined using live cell imaging. The possible importance of mitochondrial permeability transition pore (PTP) formation during PCD was indirectly examined via in vivo cyclosporine A (CsA) treatment. This treatment resulted in lace plant leaves with a significantly lower number of perforations compared to controls, and that displayed mitochondrial dynamics similar to that of non-PCD cells.'],
#   'labels': ['BACKGROUND', 'RESULTS'],
#   'meshes': ['Alismataceae',
#    'Apoptosis',
#    'Cell Differentiation',
#    'Mitochondria',
#    'Plant Leaves'],
#   'reasoning_required_pred': ['y', 'e', 's'],
#   'reasoning_free_pred': ['y', 'e', 's']},
#  'long_answer': 'Results depicted mitochondrial dynamics in vivo as PCD progresses within the lace plant, and highlight the correlation of this organelle with other organelles during developmental PCD. To the best of our knowledge, this is the first report of mitochondria and chloroplasts moving on transvacuolar strands to form a ring structure surrounding the nucleus during developmental PCD. Also, for the first time, we have shown the feasibility for the use of CsA in a whole plant system. Overall, our findings implicate the mitochondria as playing a critical and early role in developmentally regulated PCD in the lace plant.',
#  'final_decision': 'yes'}

# %% [markdown]
# ## II. Preprocessing
#
# ### i. Tokenization
#
# To represent document and prompt with the **BERT** [*cls*] **token**, **the first step is tokenization**, or **mapping texts into indices of words/ subwords using the pretrained BERT model**. Below is an example. Since BERT applied **byte pair encoding, some tokens are sub-words instead of words** (e.g. ##ap, ##se, as shown below).

# %%
transformer_name = "bert-base-uncased"
tokenizer_bert = BertTokenizer.from_pretrained(transformer_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# example reference sentence
example_ref = "i love you too much"
example_ref_tokenized = tokenizer_bert.tokenize(example_ref)
example_ref_tokenized
# Out:
# ['i', 'love', 'you', 'too', 'much']

# %% [markdown]
# ### ii. Evaluating generated response
#
# Generated answers to medical questions were evaluated using BLEU and ROUGE-L score. From the example below, we can see **the limitation of these two measures**. The **reference sentence** "*I love you too much*" **has almost the opposite meaning** than the  **predicted sentence** "*I hate you too*". However, **the bag-of-word precision-based BLEU** score and **F1-score-based ROUGH-L** score are relatively high.

# %%
# example predictied sentence
example_pred = "i hate you too"
example_pred_tokenized = tokenizer_bert.tokenize(example_pred)

example_pred_tokenized
# Out:
# ['i', 'hate', 'you', 'too']

# %%
# calculate 1-gram BLEU score

example_bleu = sentence_bleu([example_ref_tokenized],
                             example_pred_tokenized,
                             weights = [1])

print(f"Example BLEU score: {example_bleu:.3f}")
# Out:
# Example BLEU score: 0.584

# %%
# calculate ROUGe-L score
rouge = evaluate.load('rouge')

rouge_results = rouge.compute(predictions=[example_pred],
                        references=[example_ref])
print(rouge_results)
print(f"Example Rouge-L score: {rouge_results['rougeL']:.3f}")
# Out:
# {'rouge1': 0.6666666666666665, 'rouge2': 0.28571428571428575, 'rougeL': 0.6666666666666665, 'rougeLsum': 0.6666666666666665}
# Example Rouge-L score: 0.667

# %% [markdown]
# ### iii. Dataset Preparation
#
# The dataset is first turned into a panda dataframe. Then, **all contexts** (some or all sections in a structured abstract, e.g. background, methods, results, excluding the conclusion section) **were concatenated into a whole piece of text** named *abstract*.

# %%
# Convert dataset to dataframe
Dataset_l_df = Dataset_l_raw['train'].to_pandas()
Dataset_l_df.sample(5)
# Out:
#         pubid                                           question  \
# 93   14978612  Does positron emission tomography change manag...
# 692  17462393  Does normothermic normokalemic simultaneous an...
# 100  22564465  Mammographic screening in Sami speaking munici...
# 562  23774337  Does the central venous pressure predict fluid...
# 729   7664228  Discharging patients earlier from Winnipeg hos...
#
#                                                context  \
# 93   {'contexts': ['The influence of positron emiss...
# 692  {'contexts': ['Beating-heart valve surgery app...
# 100  {'contexts': ['Female citizens of Sami (the in...
# 562  {'contexts': ['Despite a previous meta-analysi...
# 729  {'contexts': ['To determine whether decreasing...
#
#                                            long_answer final_decision
# 93   Position emission tomography scanning appears ...            yes
# 692  Normothermic normokalemic simultaneous antegra...             no
# 100  Despite a lower risk of breast cancer, the Sam...            yes
# 562  There are no data to support the widespread pr...             no
# 729  Improving hospital efficiency by shortening le...             no

# %%
# concatenate contexts
def retrieve_abstract(context):
  return ' '.join(context['contexts'])

Dataset_l_df['abstract'] = Dataset_l_df['context'].apply(retrieve_abstract)

# %%
# concatenate question and the abstract from the same paper
Dataset_l_df['qa'] = Dataset_l_df['question'] + ' ' + Dataset_l_df['abstract']

# %%
Dataset_l_df = Dataset_l_df[['pubid','question', 'abstract', 'qa','long_answer', 'final_decision']]
Dataset_l_df.sample(5)
# Out:
#         pubid                                           question  \
# 612  10927144  Can p53 alterations be used to predict tumour ...
# 468  16778275  Is routine chest radiography after transbronch...
# 355  25371231  Is vitamin D insufficiency or deficiency relat...
# 586  22302658  Does limb-salvage surgery offer patients bette...
# 938  20577124  Is leptin involved in phagocytic NADPH oxidase...
#
#                                               abstract  \
# 612  To examine whether p53 tumour suppressor gene ...
# 468  Pneumothorax following flexible bronchoscopy (...
# 355  The aetiology of osteochondritis dissecans is ...
# 586  Patients with aggressive lower extremity muscu...
# 938  Hyperleptinemia and oxidative stress play a ma...
#
#                                                     qa  \
# 612  Can p53 alterations be used to predict tumour ...
# 468  Is routine chest radiography after transbronch...
# 355  Is vitamin D insufficiency or deficiency relat...
# 586  Does limb-salvage surgery offer patients bette...
# 938  Is leptin involved in phagocytic NADPH oxidase...
#
#                                            long_answer final_decision
# 612  p53 alteration detected by IHC or SSCP analysi...             no
# 468  We conclude that routine CXR after bronchoscop...             no
# 355  These first data show that a vitamin D3 defici...          maybe
# 586  These data suggest that limb-salvage surgery o...          maybe
# 938  These findings show that phagocytic NADPH oxid...            yes

# %% [markdown]
# ### iv. Representing Documents
#
# To represent documents with the **BERT** [*cls*] **token**, **tokenized documents were fed into the pretrained BERT model**. Then, **the first token embedding**, the [*cls*] embedding, **can be retrieved to represent the document**.

# %%
# load BERT tokenizer (uncased)
transformer_name = "bert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(transformer_name)

# load pretrained BERT model
model = BertModel.from_pretrained(transformer_name)

# assign device (cuda if possible)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# load to device
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# From the example above, one can observe that **the** [*cls*] **token is the** ***first*** **token when feeding the text into the pretrained model**. With this in mind, all document representations in the database can be derived.

# %%
def getBertCls(text):
  '''
  this function takes the following input:
  text to be represented by the BERT CLS token
  and gives the following output:
  a numpy array representing the text
  '''
  tok_text = tokenizer(text[:512],
                       return_tensors='pt').to(device)
  mod_output = model(**tok_text,
                     output_hidden_states=True)
  last_hidden_states = mod_output.hidden_states[-1]
  return last_hidden_states[:,0,:].cpu().detach().numpy()[0]

# %%
# create column with cls representation of document
Dataset_l_df['question_cls'] = Dataset_l_df['question'].apply(getBertCls)
Dataset_l_df['abstract_cls'] = Dataset_l_df['abstract'].apply(getBertCls)

Dataset_l_df.sample(5)
# Out:
#         pubid                                           question  \
# 555  15954832  Is minilaparoscopic inguinal hernia repair fea...
# 395  25887165  Does Sensation Return to the Nasal Tip After M...
# 527  23052500  Staging laparoscopy in patients with hepatocel...
# 335  23025584  Does stress increase imitation of drinking beh...
# 666  18472368  Does treatment duration affect outcome after r...
#
#                                               abstract  \
# 555  Laparoscopy has rapidly emerged as the preferr...
# 395  Patients usually complain about numbness in th...
# 527  Staging laparoscopy (SL) is not regularly perf...
# 335  That alcohol consumption is strongly influence...
# 666  The protraction of external beam radiotherapy ...
#
#                                                     qa  \
# 555  Is minilaparoscopic inguinal hernia repair fea...
# 395  Does Sensation Return to the Nasal Tip After M...
# 527  Staging laparoscopy in patients with hepatocel...
# 335  Does stress increase imitation of drinking beh...
# 666  Does treatment duration affect outcome after r...
#
#                                            long_answer final_decision  \
# 555  While limited by its retrospective design, the...            yes
# 395  Postoperative numbness occurs in most patients...            yes
# 527  The overall yield of SL for HCC was 7 %, and t...             no
# 335  Generally, it appears that among young male ad...             no
# 666  A proportionally longer treatment duration was...            yes
#
#                                           question_cls  \
# 555  [-0.6641139, -0.6014889, -0.13556018, -0.10516...
# 395  [-0.26579577, -0.26328933, -0.4678107, -0.1576...
# 527  [-0.5822657, -0.7911572, -0.47684184, -0.34038...
# 335  [-0.057301488, -0.21439199, -0.38715002, 0.074...
# 666  [-0.49996147, -0.12104655, -0.3541218, -0.2416...
#
#                                           abstract_cls
# 555  [-0.4979502, 0.010480256, 0.13777044, -0.58153...
# 395  [-0.31449622, -0.26738158, -0.029971201, -0.05...
# 527  [-0.42638335, -0.33983535, -0.08002636, -0.403...
# 335  [-0.24706757, -0.15074095, 0.32532862, -0.2806...
# 666  [-0.4997697, -0.35794866, 0.033892825, -0.1149...

# %% [markdown]
# ### v. Retrieve the most relevant document
#
# To retrieve the most relevant document, **cosine similarity was calculated between every question and all the abstracts**. **The abstract with the highest similarity score with the question will be retrieved**.

# %%
def calPromptCosSim(emb1, emb2):
  '''
  return the cosine similarity of the
  2 input numpy array
  '''
  result = emb1 @ emb2.T
  result /= (np.linalg.norm(emb1)*np.linalg.norm(emb2))
  return result

# %%
retrieved_abstract = list()

pubids = Dataset_l_df['pubid'].tolist()
q_embs = Dataset_l_df['question_cls'].to_numpy()
a_embs = Dataset_l_df['abstract_cls'].to_numpy()
abstracts = Dataset_l_df['abstract'].tolist()

# loop through all questions
for i in range(len(pubids)):
  # retrieve the most similar document
  similarities = calPromptCosSim(q_embs[i], np.stack(a_embs))
  idx_doc = np.argmax(similarities)
  retrieved_abstract.append([pubids[i], abstracts[idx_doc]])

retrieved_abstracts_df = pd.DataFrame(retrieved_abstract,
                                      columns=['pubid', 'abstract_r'])

# %%
# join dataset with the retrieved document
Dataset_l_df = Dataset_l_df.merge(retrieved_abstracts_df,
                                  on='pubid',
                                  how = 'inner')
Dataset_l_df.head(5)
# Out:
#       pubid                                           question  \
# 0  21645374  Do mitochondria play a role in remodelling lac...
# 1  16418930  Landolt C and snellen e acuity: differences in...
# 2   9488747  Syncope during bathing in infants, a pediatric...
# 3  17208539  Are the long-term results of the transanal pul...
# 4  10808977  Can tailored interventions increase mammograph...
#
#                                             abstract  \
# 0  Programmed cell death (PCD) is the regulated d...
# 1  Assessment of visual acuity depends on the opt...
# 2  Apparent life-threatening events in infants ar...
# 3  The transanal endorectal pull-through (TERPT) ...
# 4  Telephone counseling and tailored print commun...
#
#                                                   qa  \
# 0  Do mitochondria play a role in remodelling lac...
# 1  Landolt C and snellen e acuity: differences in...
# 2  Syncope during bathing in infants, a pediatric...
# 3  Are the long-term results of the transanal pul...
# 4  Can tailored interventions increase mammograph...
#
#                                          long_answer final_decision  \
# 0  Results depicted mitochondrial dynamics in viv...            yes
# 1  Using the charts described, there was only a s...             no
# 2  "Aquagenic maladies" could be a pediatric form...            yes
# 3  Our long-term study showed significantly bette...             no
# 4  The effects of the intervention were most pron...            yes
#
#                                         question_cls  \
# 0  [-0.5154661, -0.106142305, -0.28411922, -0.123...
# 1  [-0.3664919, -0.18892226, -0.6237057, -0.75681...
# 2  [-0.34855083, -0.34341225, -0.68562186, 0.1192...
# 3  [-0.20517431, -0.23843785, 0.013513021, -0.034...
# 4  [-0.53521794, -0.33332643, -0.3663158, -0.0693...
#
#                                         abstract_cls  \
# 0  [-0.20179763, -0.32204536, -0.32318643, 0.1764...
# 1  [-0.28828055, -0.14107008, -0.44304717, -0.286...
# 2  [-0.638743, -0.52982956, -0.69166505, -0.37416...
# 3  [-0.57676816, -0.67617077, -0.38403293, -0.354...
# 4  [-0.34828824, -0.15164366, -0.6552947, -0.3681...
#
#                                           abstract_r
# 0  To study whether exercise during pregnancy red...
# 1  Complex regional pain syndrome type I is treat...
# 2  To study whether exercise during pregnancy red...
# 3  Various factors contribute to the effective im...
# 4  To study whether exercise during pregnancy red...

# %%
# concatenate question and the abstract from the same paper
Dataset_l_df['qa_retrieved'] = Dataset_l_df['question'] + ' ' + Dataset_l_df['abstract_r']

# %%
# output dataset
path = '/content/drive/MyDrive/Duke/Spring2024/LLM/FinalProject/'


Dataset_l_df.to_csv(path+'DatasetREG_20240502.csv',
                    index=False)

# %% [markdown]
# ## C. Generate Long Answers
# Long answers were generated with a pretrained gpt-2 model.

# %%
# set random seed
set_seed(42)

# define gpt2 text generator
generator = pipeline('text-generation',
                     model='gpt2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def gen_long_response(txt):
  generator = pipeline('text-generation',
                       model='gpt2')
  gen_text = generator(txt,
                       max_new_tokens = 30,
                       num_return_sequences = 1,
                       pad_token_id=generator.tokenizer.eos_token_id)
  return gen_text[0]['generated_text'][len(txt):]

# %%
Dataset_l_df['gen_answer_q'] = Dataset_l_df['question'].apply(gen_long_response)
Dataset_l_df['gen_answer_qa'] = Dataset_l_df['qa'].apply(gen_long_response)
Dataset_l_df['gen_answer_qar'] = Dataset_l_df['qa_retrieved'].apply(gen_long_response)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
Dataset_l_df.sample(5)
# Out:
#         pubid                                           question  \
# 521  26348845  Pap smears with glandular cell abnormalities: ...
# 737  10973547  Are patients with Werlhof's disease at increas...
# 740  26163474  Is there a connection between sublingual varic...
# 660  24374414  Does health information exchange reduce redund...
# 411  18507507  The promise of specialty pharmaceuticals: are ...
#
#                                               abstract  \
# 521  Rapid prescreening (RPS) is one of the quality...
# 737  It is generally assumed, that patients with We...
# 740  Sublingual varices have earlier been related t...
# 660  Broad-based electronic health information exch...
# 411  Specialty pharmaceuticals have evolved beyond ...
#
#                                                     qa  \
# 521  Pap smears with glandular cell abnormalities: ...
# 737  Are patients with Werlhof's disease at increas...
# 740  Is there a connection between sublingual varic...
# 660  Does health information exchange reduce redund...
# 411  The promise of specialty pharmaceuticals: are ...
#
#                                            long_answer  \
# 521  Pap smears with glandular cell abnormalities a...
# 737  Patients with WD may possibly undergo cardiac ...
# 740  An association was found between sublingual va...
# 660  HIE was associated with reduced repeat imaging...
# 411  Current evidence suggests that when used in ta...
#
#                                           question_cls  \
# 521  [-0.25452468, -0.52106756, -0.2344852, -0.0410...
# 737  [-0.60479903, -0.31824994, -0.5445265, -0.0714...
# 740  [-0.31770706, -0.40249935, -0.47051668, -0.164...
# 660  [-0.37056234, -0.18045987, -0.402243, -0.13236...
# 411  [-0.026619682, 0.0021823128, -0.020715406, 0.0...
#
#                                           abstract_cls  \
# 521  [-0.5702184, -0.24906324, -0.21664818, -0.2179...
# 737  [-0.08996212, -0.3734647, -0.31098098, -0.1186...
# 740  [-0.3533773, -0.14783579, -0.46499273, -0.2138...
# 660  [-0.509178, -0.50266314, -0.09870474, -0.24097...
# 411  [-0.34382528, -0.15578249, -0.11090787, -0.145...
#
#                                             abstract_r  \
# 521  Complex regional pain syndrome type I is treat...
# 737  To determine the potential prognostic value of...
# 740  Complex regional pain syndrome type I is treat...
# 660  Specialty pharmaceuticals have evolved beyond ...
# 411  Various factors contribute to the effective im...
#
#                                           qa_retrieved  \
# 521  Pap smears with glandular cell abnormalities: ...
# 737  Are patients with Werlhof's disease at increas...
# 740  Is there a connection between sublingual varic...
# 660  Does health information exchange reduce redund...
# 411  The promise of specialty pharmaceuticals: are ...
#
#                                           gen_answer_q  \
# 521  \n\nThis is a fascinating one, because if this...
# 737  \n\nThis is not a question of "skeptical docto...
# 740   I feel like a good friend who's been studying...
# 660   How would better information exchange help to...
# 411   We're not convinced yet," says Tom Karp at Bl...
#
#                                          gen_answer_qa  \
# 521   The results indicated that only 23.3% of the ...
# 737  \n\nF ig. 1. View largeDownload slide Anterior...
# 740   Patients with different systolic blood pressu...
# 660  HIE was associated with lower survival, reduce...
# 411   The benefits of prescription-drug utilization...
#
#                                         gen_answer_qar
# 521  \n\nCONCLUSION As a consequence of the recent ...
# 737   In a FASEB, a nonfatal stroke is an establish...
# 740   At the same time, the prevalence of complex r...
# 660   What they might do. An international coalitio...
# 411  \n\npreventative and adaptive use of therapist...

# %%
# output resulting dataset
Dataset_l_df.to_csv(path+'DatasetREG_LongAns_20240502.csv',
                    index=False)

# %% [markdown]
# ## D. Evaluate Results
#
# Long answers were evaluated using one-gram BLEU score and ROUGE-L score against the ground truths.

# %% [markdown]
# ### i. BLEU Score

# %%
def cal_bleu_q(row):
  gt = row['long_answer']
  gt_tok = tokenizer_bert.tokenize(gt)
  pred = row['gen_answer_q']
  try:
    pred_tok = tokenizer_bert.tokenize(pred)
  except:
    pred_tok = []
  # Calculate BLEU score with weights
  bleu = sentence_bleu([gt_tok],
                        pred_tok,
                        weights = [1])
  return bleu

Dataset_l_df['answer_q_bleu'] = Dataset_l_df.apply(cal_bleu_q, axis=1)

# %%
def cal_bleu_qa(row):
  gt = row['long_answer']
  gt_tok = tokenizer_bert.tokenize(gt)
  pred = row['gen_answer_qa']
  try:
    pred_tok = tokenizer_bert.tokenize(pred)
  except:
    pred_tok = []
  # Calculate BLEU score with weights
  bleu = sentence_bleu([gt_tok],
                        pred_tok,
                        weights = [1])
  return bleu

Dataset_l_df['answer_qa_bleu'] = Dataset_l_df.apply(cal_bleu_qa, axis=1)

# %%
def cal_bleu_qar(row):
  gt = row['long_answer']
  gt_tok = tokenizer_bert.tokenize(gt)
  pred = row['gen_answer_qar']
  try:
    pred_tok = tokenizer_bert.tokenize(pred)
  except:
    pred_tok = []
  # Calculate BLEU score with weights
  bleu = sentence_bleu([gt_tok],
                        pred_tok,
                        weights = [1])
  return bleu

Dataset_l_df['answer_qar_bleu'] = Dataset_l_df.apply(cal_bleu_qar, axis=1)

# %%
bleus = Dataset_l_df[['answer_q_bleu', 'answer_qa_bleu','answer_qar_bleu']]
bleus.describe()
# Out:
#        answer_q_bleu  answer_qa_bleu  answer_qar_bleu
# count    1000.000000     1000.000000      1000.000000
# mean        0.097784        0.137156         0.088884
# std         0.069654        0.081002         0.052309
# min         0.000000        0.000000         0.000000
# 25%         0.046613        0.078786         0.051912
# 50%         0.081805        0.126008         0.081060
# 75%         0.134697        0.183121         0.121779
# max         0.460319        0.500000         0.343575

# %% [markdown]
# ### ii. ROUGE Score

# %%
def cal_rouge_q(row):
  gt = row['long_answer']
  pred = row['gen_answer_q']
  # Calculate ROUGE score with weights
  try:
    rouge_results = rouge.compute(predictions=[pred],
                        references=[gt])
    return rouge_results['rougeL']
  except:
    return None

Dataset_l_df['answer_q_rouge'] = Dataset_l_df.apply(cal_rouge_q, axis=1)

# %%
def cal_rouge_qa(row):
  gt = row['long_answer']
  pred = row['gen_answer_qa']
  # Calculate ROUGE score with weights
  try:
    rouge_results = rouge.compute(predictions=[pred],
                        references=[gt])
    return rouge_results['rougeL']
  except:
    return None

Dataset_l_df['answer_qa_rouge'] = Dataset_l_df.apply(cal_rouge_qa, axis=1)

# %%
def cal_rouge_qar(row):
  gt = row['long_answer']
  pred = row['gen_answer_qar']
  # Calculate ROUGE score with weights
  try:
    rouge_results = rouge.compute(predictions=[pred],
                        references=[gt])
    return rouge_results['rougeL']
  except:
    return None

Dataset_l_df['answer_qar_rouge'] = Dataset_l_df.apply(cal_rouge_qar, axis=1)

# %%
rouges = Dataset_l_df[['answer_q_rouge', 'answer_qa_rouge','answer_qar_rouge']]
rouges.describe()
# Out:
#        answer_q_rouge  answer_qa_rouge  answer_qar_rouge
# count     1000.000000      1000.000000       1000.000000
# mean         0.092140         0.126588          0.092330
# std          0.058600         0.059388          0.043708
# min          0.000000         0.000000          0.000000
# 25%          0.051282         0.086957          0.065574
# 50%          0.089888         0.125000          0.090909
# 75%          0.129032         0.160000          0.121212
# max          0.411765         0.347826          0.250000

# %%
Dataset_l_df.to_csv(path+'DatasetREG_LongAnsEval_20240502.csv',
                    index=False)

# %% [markdown]
# ### References
# 1. Jin, Qiao, et al. "Pubmedqa: A dataset for biomedical research question answering." arXiv preprint arXiv:1909.06146 (2019).
